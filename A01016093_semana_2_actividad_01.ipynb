# %% [markdown]
# # 🎓 **Maestría en Inteligencia Artificial Aplicada**
#
# ## 📈 **Curso: Procesamiento de Lenguaje Natural (Gpo 10)**
#
# ### 🏛️ Tecnológico de Monterrey
#
# #### 👨‍🏫 **Profesor titular:** Dr. Luis Eduardo Falcón Morales
# #### 👩‍🏫 **Profesor asistente:** Yetnalezi Quintas Ruiz
#
# ### 📊 **Actividad de la Semana 02 | Introducción al procesamiento de texto.**
#
# #### 📅 **23 de abril de 2025**
#
# 🧑‍💻 **A01016093:** Oscar Enrique García García

# %% [markdown]
# En esta actividad deberás utilizar los datos del siguiente archivo que se encuentra en Canvas:
#
# MNA_NLP_semana_02_Actividad_datos.txt
#
# El archivo contiene comentarios en inglés sobre servicios de comida de la página de Yelp: https://www.yelp.com/ .
#
# Son mil comentarios y forman parte del conjunto de datos que se encuentra en el Machine Learning Repository de la UCI, llamado "Sentiment Labelled Sentences": https://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences#

# %% [markdown]
# #**Parte 1. Cargamos los datos.**

# %% [markdown]
# Cargar los datos del archivo indicado y obtener una lista de longitud de 1000 strings/comentarios.
#
# Por el momento solamente requerimos las bibliotecas de Numpy y re, para el manejo de los arreglos y de las expresiones regulares en Python.
#
# En particular, no necesitarás en esta actividad la biblioteca de Pandas.
#
# ###**NOTA: En esta actividad no debes importar nada más, con estas dos bibliotecas será *suficiente*.**

# %%
import numpy as np    # importamos Numpy para el manejo de los arreglos.
import re             # importamos re para el manejo de las expresiones regulares.
import tabulate as tab

# %%
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/NLP2025_Rebull/Activity01/MNA_NLP_semana_02_Actividad_datos.txt'
# Out:
# Mounted at /content/drive

# %%
# Ejecuta las siguientes instrucciones para cargar la información del achivo dado:

with open(file_path,        # puedes actualizar la ruta a tu archivo, en dado caso.
          mode='r',     # abrimos el archivo en modo lectura.
          ) as f:
    docs = f.readlines()    # separamos cada comentario por líneas

f.close()  # ya que tenemos la información en la variable docs, cerramos el archivo

# %%
type(docs) == list   # Verifica que tu variable "docs" es una lista
# Out:
# True

# %%
len(docs)==1000  # verifica que la longitud de "docs" es de mil comentarios.
# Out:
# True

# %%
docs[0:10]     # observa algunos de los primeros comentarios
# Out:
# ['Wow... Loved this place.\n',
#  'Crust is not good.\n',
#  'Not tasty and the texture was just nasty.\n',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.\n',
#  'The selection on the menu was great and so were the prices.\n',
#  'Now I am getting angry and I want my damn pho.\n',
#  "Honeslty it didn't taste THAT fresh.)\n",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.\n',
#  'The fries were great too.\n',
#  'A great touch.\n']

# %% [markdown]
# #**Parte 2: sección de preguntas (regex).**

# %% [markdown]
# ##**Instrucciones:**
#
# ###**A continuación deberás contestar cada una de las preguntas que te piden usando expresiones regulares (regex).**
#
# ###**Por el momento no hay restricción en cuanto al número de líneas de código que agregues, pero trata de incluir las mínimas posibles.**

# %% [markdown]
# * Se agrega esta función que nos permitirá imprimir los resultados de las preguntas en un formato más legible

# %%
def print_table(headers, data):

    formatted_data = [[item] for item in data]
    print(tab.tabulate(formatted_data, headers=[headers], tablefmt="grid"))

# %% [markdown]
# *   **Pregunta 1.**
#
# Busca y elimina todos los saltos de línea '\n' que se encuentran al final de cada comentario.
#
# Una vez finalizado, imprime los primeros 10 comentarios del resultado obtenido.

# %% [markdown]
# 🤓 **Explicación de expresión regular**
#
# **`\n:`**Encuentra todos los saltos de línea.
#
# `re.sub(pattern, repl, string)`: Reemplaza todas las ocurrencias de "pattern", por el reemplazo "repl", dentro de la cadena "string".
#
# **`Resultado`**: reemplaza todos los saltos de línea, por una cadena vacía.

# %%
comm_transf = [re.sub(r'\n$', '', comentario) for comentario in docs]
print_table('Primeros 10 comentarios sin salto de línea', comm_transf[:10])
# Out:
# +-----------------------------------------------------------------------------------------------------------------+
# | Primeros 10 comentarios sin salto de línea                                                                      |
# +=================================================================================================================+
# | Wow... Loved this place.                                                                                        |
# +-----------------------------------------------------------------------------------------------------------------+
# | Crust is not good.                                                                                              |
# +-----------------------------------------------------------------------------------------------------------------+
# | Not tasty and the texture was just nasty.                                                                       |
# ...

# %% [markdown]
# *   **Pregunta 2.**
#
# Busca e imprime todas las palabras que terminan con dos o más signos de admiración seguidos, por ejemplo "!!!".
#
# Debes imprimir tanto la palabra como la totalidad de signos de admiración que le siguen.
#
# Indica cuántos resultados obtuviste.

# %% [markdown]
# 🤓 **Explicación de expresión regular**
#
# **`\b:`** Word boundary. Hace match con la posición entre un caracter alfanumérico (a-zA-Z0-9_) y uno no alfanumérico. En este caso, hace match con el inicio de la palabra que puede estar precedido por el inicio del comentario, por un espacio en blanco, una coma, etc.
#
# **`\w:`** Word character. Contempla todos los caracteres alfanuméricos (a-zA-Z0-9_).
#
# **`+:`** Contempla una o más ocurrencias del caracter anterior (word character).
#
# **`!:`** Busca el caracter !, dentro de la cadena de texto.
#
# **`{2,}:`** Busca al menos 2 ocurrencias del caracter anterior (!), dentro de la cadena de texto.
#
# `re.findall(pattern, string)`: Encuentra las ocurrencias que cumplen con el patrón pattern, dentro de la cadena string.
#
# **`Resultado`**: Hace match con todas las palabras individuales, que comiencen con algún caracter alfanumérico y acaben con dos o más "!".

# %%
palab_2_adm = [match for comm in comm_transf for match in re.findall(r'\b\w+!{2,}', comm)]
print_table('Palabras que acaban con dos o más signos de admiración seguidos', palab_2_adm)
print(f'Cantidad de palabras encontradas: {len(palab_2_adm)}')
# Out:
# +-------------------------------------------------------------------+
# | Palabras que acaban con dos o más signos de admiración seguidos   |
# +===================================================================+
# | Firehouse!!!!!                                                    |
# +-------------------------------------------------------------------+
# | APPETIZERS!!!                                                     |
# +-------------------------------------------------------------------+
# | amazing!!!                                                        |
# +-------------------------------------------------------------------+
# | buffet!!!                                                         |
# +-------------------------------------------------------------------+
# | good!!                                                            |
# +-------------------------------------------------------------------+
# ...

# %% [markdown]
# *   **Pregunta 3.**
#
# Busca e imprime todas las palabras que están escritas totalmente en mayúsculas. Cada coincidencia debe ser una sola palabra.
#
# Indica cuántas palabras encontraste.

# %% [markdown]
# 🤓 **Explicación de expresión regular**
#
# **`\b:`** Word boundary. Hace match con la posición entre un caracter alfanumérico (a-zA-Z0-9_) y uno no alfanumérico. En este caso, hace match con el inicio y el final de la palabra   que puede ser el inicio del comentario, el inicio de la palabra o el final de la misma.
#
# **`[A-ZÁÉÍÓÚ]:`** Clases de caracteres []. Se utilizan para indicar que se hace match con cualquiera de los caracteres dentro de los "[]". En este caso, se haría match con cualquier letra mayúscula, incluyendo las mayúsculas acentuadas.
#
# **`+:`** Contempla una o más ocurrencias del caracter anterior (clase de caracteres).
#
# `re.findall(pattern, string)`: Encuentra las ocurrencias que cumplen con el patrón pattern, dentro de la cadena string.
#
# **`Resultado`**: Hace match con todas las palabras individuales, que estén completamente en mayúsculas.

# %%
palab_mayusculas = list(set(match for comm in comm_transf for match in re.findall(r'\b[A-ZÁÉÍÓÚ]+\b', comm))) #Evaluando también las mayúsculas con acentos

print_table('Palabras que están escritas totalmente en mayúsculas', palab_mayusculas)
print(f'Cantidad de palabras encontradas: {len(palab_mayusculas)}')
# Out:
# +--------------------------------------------------------+
# | Palabras que están escritas totalmente en mayúsculas   |
# +========================================================+
# | LOVED                                                  |
# +--------------------------------------------------------+
# | REALLY                                                 |
# +--------------------------------------------------------+
# | TV                                                     |
# +--------------------------------------------------------+
# | UNREAL                                                 |
# +--------------------------------------------------------+
# | BACK                                                   |
# +--------------------------------------------------------+
# | BARGAIN                                                |
# +--------------------------------------------------------+
# | DELICIOUS                                              |
# ...

# %% [markdown]
# *   **Pregunta 4.**
#
# Busca e imprime los comentarios en donde todos los caracteres alfabéticos (letras) están en mayúsculas.
#
# Cada coincidencia encontrada debe ser todo el comentario/enunciado.
#
# Indica cuántos resultados obtuviste.

# %% [markdown]
# 🤓 **Explicación de expresión regular**
#
# **`^:`** Hace match con el inicio del string (comentario).
#
# **`[A-ZÁÉÍÓÚ0-9\s\W]:`** Clases de caracteres []. Se utilizan para indicar que se hace match con cualquiera de los caracteres dentro de los "[]". En este caso, se haría match con cualquier letra mayúscula, incluyendo las mayúsculas acentuadas, así como cualquier dígito, cualquier espacio en blanco y cualquier caracter no alfanumérico.
#
# **`+:`** Contempla una o más ocurrencias del caracter anterior (clase de caracteres).
#
# **`$:`** Hace match con el final del string (comentario).
#
# `re.findall(pattern, string)`: Encuentra las ocurrencias que cumplen con el patrón pattern, dentro de la cadena string.
#
# **`Resultado`**: Hace match con todos los comentarios que contengan todos los caracteres alfabéticos en mayúsculas.

# %%
enun_mayus = [comm for comm in comm_transf for match in re.findall(r'^[A-ZÁÉÍÓÚ0-9\s\W]+$', comm)] #Evaluando también las mayúsculas con acentos
print_table('Comentarios con todos los caracteres alfabéticos en mayúsculas', enun_mayus)
print(f'Cantidad de enunciados encontradas: {len(enun_mayus)}')
# Out:
# +----------------------------------------------------------------------+
# | Comentarios con todos los caracteres alfabéticos en mayúsculas       |
# +======================================================================+
# | DELICIOUS!!                                                          |
# +----------------------------------------------------------------------+
# | RUDE & INCONSIDERATE MANAGEMENT.                                     |
# +----------------------------------------------------------------------+
# | WILL NEVER EVER GO BACK AND HAVE TOLD MANY PEOPLE WHAT HAD HAPPENED. |
# +----------------------------------------------------------------------+
# | TOTAL WASTE OF TIME.                                                 |
# +----------------------------------------------------------------------+
# | AVOID THIS ESTABLISHMENT!                                            |
# +----------------------------------------------------------------------+
# ...

# %% [markdown]
# *   **Pregunta 5.**
#
# Busca e imprime todas las palabras que tengan una vocal acentuada, del tipo á, é, í, ó, ú.
#
# Indica cuántos resultados obtuviste.

# %% [markdown]
# 🤓 **Explicación de expresión regular**
#
# **`\b:`** Word boundary. Hace match con la posición entre un caracter alfanumérico (a-zA-Z0-9_) y uno no alfanumérico. En este caso, hace match con el inicio y el final de la palabra   que puede ser el inicio del comentario, el inicio de la palabra o el final de la misma.
#
# **`\w:`** Contempla cualquier caracter alfanumérico (a-zA-Z0-9_).
#
# **`*:`** Contempla cero o más ocurrencias del caracter anterior (caracter alfanumérico).
#
# **`[áéíóú]:`** Clases de caracteres []. Se utilizan para indicar que se hace match con cualquiera de los caracteres dentro de los "[]". En este caso, se haría match con cualquier letra minúscula acentuada.
#
# **`+:`** Contempla una o más ocurrencias del caracter anterior (clase de caracteres).
#
# `re.findall(pattern, string)`: Encuentra las ocurrencias que cumplen con el patrón pattern, dentro de la cadena string.
#
# **`Resultado`**: Hace match con todas las palabras que tengan alguna letra acentuada (minúscula).

# %%
palab_acent = list(set(match for comm in comm_transf for match in re.findall(r'\b\w*[áéíóú]+\w*\b', comm))) #Se deja el +, en caso de que existieran comentarios con múltiples vocales con acentos. E.g. Caféééé

print_table('Palabras que tienen alguna vocal acentuada', palab_acent)
print(f'Cantidad de palabras encontradas: {len(palab_acent)}')
# Out:
# +----------------------------------------------+
# | Palabras que tienen alguna vocal acentuada   |
# +==============================================+
# | Café                                         |
# +----------------------------------------------+
# | puréed                                       |
# +----------------------------------------------+
# | fiancé                                       |
# +----------------------------------------------+
# Cantidad de palabras encontradas: 3

# %% [markdown]
# *   **Pregunta 6.**
#
# Busca e imprime todas las cantidades numéricas monetarias, enteras o con decimales, que inician con el símbolo $\$$.
#
# Indica cuántos resultados obtuviste.

# %% [markdown]
# 🤓 **Explicación de expresión regular**
#
# **`\$:`** Hace match con un símbolo de $.
#
# **`\d:`** Contempla cualquier dígito (0-9).
#
# **`+:`** Contempla una o más ocurrencias del caracter anterior (dígito).
#
# **`(?:\.\d+):`** Grupo no capturante. Hace match con la parte decimal de la cantidad (un punto, más 1 o más dígitos). Los caracteres "?:" son para que no solo se devuelva el string que hace match con el patrón dentro de los paréntesis.
#
# **`?:`** Indica que el grupo anterior es opcional. La cantidad puede ser un entero o un flotante.
#
# `re.findall(pattern, string)`: Encuentra las ocurrencias que cumplen con el patrón pattern, dentro de la cadena string.
#
# **`Resultado`**: Hace match con todas las cantidades que inician con $.

# %%
cant_mon = [match for comm in comm_transf for match in re.findall(r'\$\d+(?:\.\d+)?', comm)]

print_table('Cantidades que inician con $', cant_mon)
print(f'Cantidades encontradas: {len(cant_mon)}')
# Out:
# +--------------------------------+
# | Cantidades que inician con $   |
# +================================+
# | $20                            |
# +--------------------------------+
# | $4.00                          |
# +--------------------------------+
# | $17                            |
# +--------------------------------+
# | $3                             |
# +--------------------------------+
# | $35                            |
# +--------------------------------+
# | $7.85                          |
# +--------------------------------+
# | $12                            |
# +--------------------------------+
# | $11.99                         |
# +--------------------------------+
# Cantidades encontradas: 8

# %%
#Si solamente se quisiera obtener la cantidad en formato numérico (sin $)

cant_mon = [match for comm in comm_transf for match in re.findall(r'\$(\d+(?:\.\d+)?)', comm)]

print_table('Cantidades que inician con $', cant_mon)
print(f'Cantidades encontradas: {len(cant_mon)}')
# Out:
# +--------------------------------+
# |   Cantidades que inician con $ |
# +================================+
# |                          20    |
# +--------------------------------+
# |                           4    |
# +--------------------------------+
# |                          17    |
# +--------------------------------+
# |                           3    |
# +--------------------------------+
# |                          35    |
# +--------------------------------+
# |                           7.85 |
# +--------------------------------+
# |                          12    |
# +--------------------------------+
# |                          11.99 |
# +--------------------------------+
# Cantidades encontradas: 8

# %% [markdown]
# *   **Pregunta 7.**
#
# Busca e imprime todas las palabras que sean variantes de la palabra "love", sin importar si incluyen mayúsculas o minúsculas, o la manera en que esté conjugada o alguna otra variación que se haga con dicha palabra.
#
# Indica cuántos resultados obtuviste.

# %% [markdown]
# 🤓 **Explicación de expresión regular**
#
# **`\b:`** Word boundary. Hace match con la posición entre un caracter alfanumérico (a-zA-Z0-9_) y uno no alfanumérico. En este caso, hace match con el inicio y el final de la palabra   que puede ser el inicio del comentario, el inicio de la palabra o el final de la misma.
#
# **`lov:`** Busca la cadena "lov".
#
# **`\w:`** Contempla cualquier caracter alfanumérico (a-zA-Z0-9_).
#
# **`+:`** Contempla una o más ocurrencias del caracter anterior (caracter alfanumérico).
#
#
# `re.findall(pattern, string, re.IGNORECASE)`: Encuentra las ocurrencias que cumplen con el patrón pattern, dentro de la cadena string, sin importar si está o no en mayúsculas.
#
# **`Resultado`**: Hace match con todas las palabras variantes (sin importar si son mayúsculas o minúsculas) que inicien con lov.

# %%
pal_love = [match for comm in comm_transf for match in re.findall(r'\blov\w+\b', comm, re.IGNORECASE)]

print_table('Palabras variantes de "love"', pal_love)
print(f'Cantidad de palabras encontradas: {len(pal_love)}')
# Out:
# +--------------------------------+
# | Palabras variantes de "love"   |
# +================================+
# | Loved                          |
# +--------------------------------+
# | loved                          |
# +--------------------------------+
# | Loved                          |
# +--------------------------------+
# | love                           |
# +--------------------------------+
# | loves                          |
# +--------------------------------+
# | LOVED                          |
# +--------------------------------+
# | lovers                         |
# +--------------------------------+
# | loving                         |
# +--------------------------------+
# | love                           |
# +--------------------------------+
# | lovers                         |
# +--------------------------------+
# | Love                           |
# +--------------------------------+
# | loved                          |
# +--------------------------------+
# ...

# %% [markdown]
# * Considerando palabras distintas (case-insensitive)
#
# La siguiente sección, aunque no se menciona en las instrucciones, permite obtener las palabras ÚNICAS derivadas de la palabra "love", sin importar si están en mayúsculas o no.

# %%
pal_love = list(set(match.lower() for comm in comm_transf for match in re.findall(r'\blov\w*\b', comm, re.IGNORECASE)))

print_table('Palabras variantes de "love"', pal_love)
print(f'Cantidad de palabras encontradas: {len(pal_love)}')
# Out:
# +--------------------------------+
# | Palabras variantes de "love"   |
# +================================+
# | loved                          |
# +--------------------------------+
# | love                           |
# +--------------------------------+
# | lovely                         |
# +--------------------------------+
# | loves                          |
# +--------------------------------+
# | loving                         |
# +--------------------------------+
# | lover                          |
# +--------------------------------+
# | lovers                         |
# +--------------------------------+
# Cantidad de palabras encontradas: 7

# %% [markdown]
# *   **Pregunta 8.**
#
# Busca e imprime todas las palabras, variantes de "so" y "good", que tengan dos o más "o" en "so" y 3 o más "o" en good.
#
# Indica cuántas encontraste.

# %% [markdown]
# 🤓 **Explicación de expresión regular**
#
# **`s+:`** Hace match con una o más ocurrencias de la letra "s". Se decidió realizar de esta forma, con el fin de incluir posibles coincidencias como "ssssooo".
#
# **`o{2,}:`** Hace match con al menos dos ocurrencias de la letra "o".
#
# **`\b:`** Word boundary. Hace match con la posición entre un caracter alfanumérico (a-zA-Z0-9_) y uno no alfanumérico. En este caso, hace match el final de la palabra.
#
# **`|:`** Operador OR. Hace match con cualquiera de los dos patrones.
#
# **`g+:`** Hace match con una o más ocurrencias de la letra "g". Se decidió realizar de esta forma, con el fin de incluir posibles coincidencias como "gggoooood".
#
# **`o{3,}:`** Hace match con al menos tres ocurrencias de la letra "o".
#
# **`d+:`** Hace match con al menos una ocurrencia de la letra "d".
#
#
# `re.findall(pattern, string, re.IGNORECASE)`: Encuentra las ocurrencias que cumplen con el patrón pattern, dentro de la cadena string, sin importar si está o no en mayúsculas.
#
# **`Resultado`**: Hace match con todas las variantes de la palabra "so" o "good", que tengan dos o más "o" para "so" o tres o más para "good"

# %%
pal_so_good = [match for comm in comm_transf for match in re.findall(r's+o{2,}\b|\bg+o{3,}d+\b', comm, re.IGNORECASE)] #Se incluye el + para s, g y d, con el fin de considerar posibles variaciones como ssooo o ggooodd

print_table('Palabras variantes de "so" y "good"', pal_so_good)
print(f'Cantidad de palabras encontradas: {len(pal_so_good)}')
# Out:
# +---------------------------------------+
# | Palabras variantes de "so" y "good"   |
# +=======================================+
# | Sooooo                                |
# +---------------------------------------+
# | soooo                                 |
# +---------------------------------------+
# | gooodd                                |
# +---------------------------------------+
# | soooooo                               |
# +---------------------------------------+
# | soooo                                 |
# +---------------------------------------+
# Cantidad de palabras encontradas: 5

# %% [markdown]
# *   **Pregunta 9.**
#
# Busca e imprime todas las palabras que tengan una longitud mayor estrictamente a 10 caracteres alfabéticos.
#
# No se consideran los signos de puntuación o caracteres especiales en la longitud de estas cadenas, solo caracteres alfabéticos en mayúsculas o minúsculas.
#
# Indica la cantidad de palabras encontradas.

# %% [markdown]
# 🤓 **Explicación de expresión regular**
#
# **`\b:`** Word boundary. Hace match con la posición entre un caracter alfanumérico (a-zA-Z0-9_) y uno no alfanumérico. En este caso, hace match con el inicio del enunciado, el inicio de la palabra o el final de la misma.
#
# **`\w{11,}:`** Contempla al menos 11 ocurrencias de cualquier caracter alfanumérico (a-zA-Z0-9_).
#
#
# `re.findall(pattern, string)`: Encuentra las ocurrencias que cumplen con el patrón pattern, dentro de la cadena string.
#
# **`Resultado`**: Hace match con todas las palabras que cuenten con al menos 11 caracteres alfanuméricos.

# %%
pal_10 = [match for comm in comm_transf for match in re.findall(r'\b\w{11,}\b', comm)]

print_table('Palabras con más de 10 caracteres"', pal_10)
print(f'Cantidad de palabras encontradas: {len(pal_10)}')
# Out:
# +--------------------------------------+
# | Palabras con más de 10 caracteres"   |
# +======================================+
# | recommendation                       |
# +--------------------------------------+
# | recommended                          |
# +--------------------------------------+
# | overwhelmed                          |
# +--------------------------------------+
# | inexpensive                          |
# +--------------------------------------+
# | establishment                        |
# +--------------------------------------+
# | imaginative                          |
# +--------------------------------------+
# | opportunity                          |
# +--------------------------------------+
# | experiencing                         |
# +--------------------------------------+
# | underwhelming                        |
# +--------------------------------------+
# | relationship                         |
# +--------------------------------------+
# ...

# %% [markdown]
# *   **Pregunta 10.**
#
# Busca e imprime todas las palabras que inician con una letra mayúscula y terminan con una minúscula, pero que además no sea la primera palabra del comentario/string.
#
# Indica la cantidad de resultados obtenidos.

# %% [markdown]
# 🤓 **Explicación de expresión regular**
#
# **`\s:`** Hace match con cualquier espacio en blanco. Esto sirve para determinar que no es la primera palabra del string.
#
# **`[A-Z]:`** Hace match con cualquier letra mayúscula. Así determinamos que la palabra empieza con mayúscula.
#
# **`[a-zA-Z]*:`** Hace match con cero o más ocurrencias de cualquier letra, ya sea en mayúscula o minúscula.
#
# **`[a-z]:`** Hace match con cualquier letra minúscula. Así determinamos que la palabra acaba con minúscula.
#
# **`\b:`** Word boundary. Hace match con la posición entre un caracter alfanumérico (a-zA-Z0-9_) y uno no alfanumérico. En este caso, hace match el final de la palabra.
#
#
# `re.findall(pattern, string)`: Encuentra las ocurrencias que cumplen con el patrón pattern, dentro de la cadena string.
#
# **`Resultado`**: Hace match con todas las palabras que inician con mayúscula, acaban con minúscula y no son la primera letra del comentario.

# %%
pal_mayus_minus = [match for comm in comm_transf for match in re.findall(r'\s([A-Z][a-zA-Z]*[a-z]\b)', comm)]

print_table('Palabras que inician con mayúscula, terminan con minúscula y además no son la primera palabra del comentario', pal_mayus_minus)
print(f'Cantidad de palabras encontradas: {len(pal_mayus_minus)}')
# Out:
# +----------------------------------------------------------------------------------------------------------------+
# | Palabras que inician con mayúscula, terminan con minúscula y además no son la primera palabra del comentario   |
# +================================================================================================================+
# | Loved                                                                                                          |
# +----------------------------------------------------------------------------------------------------------------+
# | May                                                                                                            |
# +----------------------------------------------------------------------------------------------------------------+
# | Rick                                                                                                           |
# ...

# %% [markdown]
# *   **Pregunta 11.**
#
# Busca e imprime la secuencia de dos o más palabras que están separadas por un guion, "-", sin que tengan espacios en blanco entre ellas.
#
# Por ejemplo "Go-Kart" sería válido, pero "Go  -Kart" o "Go  -  Kart" no lo serían.
#
# Indica la cantidad de resultados obtenidos.

# %% [markdown]
# 🤓 **Explicación de expresión regular**
#
# **`\b:`** Word boundary. Hace match con la posición entre un caracter alfanumérico (a-zA-Z0-9_) y uno no alfanumérico. En este caso, hace match con el inicio del enunciado, el inicio de la palabra o el final de la misma.
#
# **`\w+:`** Hace match con 1 o más instancias de cualquier caracter alfanumérico (a-zA-Z0-9_).
#
# **`(?:-\w+):`** Grupo no capturante. Hace match con 1 guión, seguido de 1 o más ocurrencias de caracter alfanumérico (a-zA-Z0-9_). Los caracteres "?:" son para que no solo se devuelva el string que hace match con el patrón dentro de los paréntesis.
#
# **`{1,}:`** Hace match con 1 o más ocurrencias del patrón anterior (Grupo no capturante). Con esto logramos también recuperar palabras separadas por más de un guión. E.g. been-stepped-in-and-tracked-everywhere
#
#
# `re.findall(pattern, string)`: Encuentra las ocurrencias que cumplen con el patrón pattern, dentro de la cadena string.
#
# **`Resultado`**: Hace match con todas las palabras separadas por guiones y que no tienen espacio en blanco entre ellas.

# %%
pal_guiones = [match for comm in comm_transf for match in re.findall(r'\b\w+(?:-\w+){1,}\b', comm)]

print_table('Palabras que están separadas por guiones', pal_guiones)
print(f'Cantidad de palabras encontradas: {len(pal_guiones)}')
# Out:
# +--------------------------------------------+
# | Palabras que están separadas por guiones   |
# +============================================+
# | flat-lined                                 |
# +--------------------------------------------+
# | hands-down                                 |
# +--------------------------------------------+
# | must-stop                                  |
# +--------------------------------------------+
# | sub-par                                    |
# +--------------------------------------------+
# | Service-check                              |
# +--------------------------------------------+
# | in-house                                   |
# +--------------------------------------------+
# | been-stepped-in-and-tracked-everywhere     |
# +--------------------------------------------+
# | multi-grain                                |
# +--------------------------------------------+
# | to-go                                      |
# ...

# %% [markdown]
# *   **Pregunta 12.**
#
# Busca e imprime todas las palabras que terminan en "ing" o "ed".
#
# Indica la cantidad de palabras que encontraste de cada una.

# %% [markdown]
# 🤓 **Explicación de expresión regular**
#
# **`\b:`** Word boundary. Hace match con la posición entre un caracter alfanumérico (a-zA-Z0-9_) y uno no alfanumérico. En este caso, hace match con el inicio y el final de la palabra.
#
# **`\w+:`** Hace match con una o más ocurrencias de cualquier caracter alfanumérico (a-zA-Z0-9_).
#
# **`ing:`** Hace match con los caracteres "ing".
#
# **`ed:`** Hace match con los caracteres "ed".
#
#
# `re.findall(pattern, string)`: Encuentra las ocurrencias que cumplen con el patrón pattern, dentro de la cadena string.
#
# **`Resultado`**: Recupera todas las palabras que terminan en ing o en ed.

# %%
# Patrón original
patron_ing = r"\b\w+ing\b"
patron_ed  = r"\b\w+ed\b"

palabras_ing = []
palabras_ed  = []

for comentario in comm_transf:
    # búsqueda sin distinguir mayúsculas/minúsculas
    matches_ing = re.findall(patron_ing, comentario, re.IGNORECASE)
    matches_ed  = re.findall(patron_ed, comentario, re.IGNORECASE)
    # convertir todo a minúsculas para lista homogénea
    palabras_ing.extend([w.lower() for w in matches_ing])
    palabras_ed.extend([w.lower() for w in matches_ed])

# Mostrar resultados
total_ing = print_table('Palabras que terminan en ing', palabras_ing)
print(f'Cantidad de palabras que terminan en ing: {len(palabras_ing)}\n')

total_ed = print_table('Palabras que terminan en ed', palabras_ed)
print(f'Cantidad de palabras que terminan en ed: {len(palabras_ed)}')
# Out:
# +--------------------------------+
# | Palabras que terminan en ing   |
# +================================+
# | during                         |
# +--------------------------------+
# | getting                        |
# +--------------------------------+
# | being                          |
# +--------------------------------+
# | being                          |
# +--------------------------------+
# | amazing                        |
# +--------------------------------+
# | running                        |
# +--------------------------------+
# | redeeming                      |
# +--------------------------------+
# | getting                        |
# +--------------------------------+
# | thing                          |
# +--------------------------------+
# | dressing                       |
# +--------------------------------+
# | refreshing                     |
# +--------------------------------+
# | running                        |
# +--------------------------------+
# ...

# %% [markdown]
# #**Parte 3. Proceso de limpieza.**

# %% [markdown]
# *   **Pregunta 13.**
#
# Ahora realiza un proceso de limpieza del corpus que incluya los siguientes procesos:
#
# *   Solo se deben considerar caracteres alfabéticos. Es decir, se eliminan todos los signos de puntuación y caracteres especiales.
# *   Todos los caracteres alfabéticos se transforman a minúsculas.
# *   Se deben eliminar todos los espacios en blanco adicionales que se puedan encontrar en cada comentario.
#
# Al finalizar dicho proceso de limpieza, imprime el resultado de los primeros 10 comentarios resultantes.

# %%
def limpieza(texto):
    texto = re.sub(r'[^a-zA-Z\s]', '', texto)
    texto = texto.lower()
    texto = re.sub(r'\s+', ' ', texto)
    return texto.strip()

# %%
comm_limpio = [limpieza(c) for c in comm_transf]
print_table('Comentarios limpios', comm_limpio[:10])
# Out:
# +----------------------------------------------------------------------------------------------------------------+
# | Comentarios limpios                                                                                            |
# +================================================================================================================+
# | wow loved this place                                                                                           |
# +----------------------------------------------------------------------------------------------------------------+
# | crust is not good                                                                                              |
# +----------------------------------------------------------------------------------------------------------------+
# | not tasty and the texture was just nasty                                                                       |
# ...

# %% [markdown]
# *   **Pregunta 14.**
#
# Con el resultado de la limpieza obtenido en la pregunta anterior, realiza ahora un proceso de tokenización por palabras del corpus.
#
# Es decir, al final de este proceso de tokenización, debes tener como resultado una lista de listas, donde cada comentario estará tokenizado por palabras.
#
# Al terminar calcula el total de tokens obtenido en todo el corpus.

# %%
comms_token = [comentario.split(' ') for comentario in comm_limpio]
total_tokens = sum(len(comentario) for comentario in comms_token)

print(comms_token[:3])
print(f"Total de tokens: {total_tokens}")
# Out:
# [['wow', 'loved', 'this', 'place'], ['crust', 'is', 'not', 'good'], ['not', 'tasty', 'and', 'the', 'texture', 'was', 'just', 'nasty']]
# Total de tokens: 10777

# %% [markdown]
# *   **Pregunta 15.**
#
# Finalmente, en este ejercicio definiremos nuestro conjunto de palabras "stopwords", las cuales deberás eliminar de todo el corpus.
#
# Recuerda que ejemplos de stopwords son artículos, adverbios, conectivos, etcétera, que tienen frecuencias de aparición muy altas en cualquier documento, pero que no brindan mucho significado en cuanto al significado de un enunciado.
#
# Con base a la lista de stopwords que se te proporciona, realiza un proceso de limpieza eliminando todas estas palabras del corpus obtenido en el ejercicio anterior.
#
# Obtener cuántos tokens/palabras quedan finalmente en todo el corpus.
#
# Obtener cuántos de estos tokens/palabras son diferentes, es decir, cuántos tokens únicos tendrá lo que llamaremos más adelante nuestro vocabulario.

# %%
# Considera la siguiente lista como tu conjunto de stopwords:
mis_stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'should', 'now', 'll']

# %%
corpus_filtrado = [
    [token for token in comentario if token not in mis_stopwords]
    for comentario in comms_token
]

corpus_filtrado[:3]
# Out:
# [['wow', 'loved', 'place'],
#  ['crust', 'not', 'good'],
#  ['not', 'tasty', 'texture', 'nasty']]

# %%
tokens_filtrados = sum(len(comentario) for comentario in corpus_filtrado)

tokens_unicos = set([palabra for comentario in corpus_filtrado for palabra in comentario])
total_tokens_unicos = len(tokens_unicos)

print(f"Total de tokens, después de filtros: {tokens_filtrados}")
print(f"Total de tokens únicos ->vocabulario: {total_tokens_unicos}")
# Out:
# Total de tokens, después de filtros: 5776
# Total de tokens únicos ->vocabulario: 1941

# %% [markdown]
# *   **Comentarios**
#
# Incluye finalmente tus comentarios de la actividad.

# %% [markdown]
# Con esta actividad, se demostró el uso de las expresiones regulares dentro del procesamiento de texto. Como vimos en los diferentes ejercicios, las expresiones regulares no solo nos permiten encontrar patrones o extraer enunciados a partir de nuestras fuentes de datos, sino que también nos pueden servir para hacer un preprocesamiento de nuestros datos y, así, poder construir nuestros tokens y vocabulario que posteriormente servirá como base para nuestros modelos/aplicaciones de NLP.
#
# Por otro lado, también pudimos demostrar cómo las diferentes estructuras de datos dentro de Python (listas, sets), así como las diferentes funciones y librerías (re, list comprehension, find, etc.), nos pueden ayudar a manejar de mejor forma nuestros datos y obtener los resultados esperados (e.g. valores únicos, case-insensitive, etc.) de forma eficiente. Esto es de gran ayuda por ejemplo para LLMs/Chatbots que necesitan realizar consultas y manejo de datos de forma altamente eficiente.
#
# Espero el conocimiento de las próximas semanas y ver cómo podemos aplicar todas estas técnicas ya en alguna solución de NLP.

# %% [markdown]
# ##**Fin de la Actividad de la semana 2.**
